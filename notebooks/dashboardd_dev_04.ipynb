# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install streamlit pyngrok tf-keras-vis fpdf2 plotly -q
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content
# !git clone https://github.com/ipshitabhardwaj/Disaster-Severity.git
# %cd Disaster-Severity
# !git checkout rishika/streamlit-app
# Out:
# /content
# fatal: destination path 'Disaster-Severity' already exists and is not an empty directory.
# /content/Disaster-Severity
# Already on 'rishika/streamlit-app'
# Your branch is ahead of 'origin/rishika/streamlit-app' by 18 commits.
#   (use "git push" to publish your local commits)

# %%
import os

drive_folder = '/content/drive/MyDrive/Project43_DisasterSeverity/'
print("Folder exists:", os.path.exists(drive_folder))

if os.path.exists(drive_folder):
    for root, dirs, files in os.walk(drive_folder):
        for f in files:
            print(os.path.join(root, f))
else:
    # shayad folder ka naam thoda alag ho, MyDrive ka top-level dekh lete hain
    print("MyDrive contents:")
    for f in os.listdir('/content/drive/MyDrive/'):
        print(f)
# Out:
# Folder exists: True

# %%
import os

drive_folder = '/content/drive/MyDrive/Project43_DisasterSeverity/'
files = os.listdir(drive_folder)
for f in files:
    print(f)
# Out:
# models
# outputs
# logs

# %%
import os

models_folder = '/content/drive/MyDrive/Project43_DisasterSeverity/models/'

try:
    files = os.listdir(models_folder)
    if len(files) == 0:
        print("Folder empty hai")
    else:
        for f in files:
            print(f)
except Exception as e:
    print("Error:", e)
# Out:
# Folder empty hai

# %%
import os

base = '/content/drive/MyDrive/Project43_DisasterSeverity/'

print("--- Top level ---")
for f in os.listdir(base):
    print(f)

print("\n--- outputs folder ---")
outputs_folder = os.path.join(base, 'outputs')
if os.path.exists(outputs_folder):
    for f in os.listdir(outputs_folder):
        print(f)

print("\n--- logs folder ---")
logs_folder = os.path.join(base, 'logs')
if os.path.exists(logs_folder):
    for f in os.listdir(logs_folder):
        print(f)
# Out:
# --- Top level ---
# models
# outputs
# logs
#
# --- outputs folder ---
#
# --- logs folder ---

# %%
import os

for root, dirs, files in os.walk('/content/drive/MyDrive/'):
    for f in files:
        if f.endswith('.h5'):
            print(os.path.join(root, f))
# Out:
# /content/drive/MyDrive/b0_phase1.h5
# /content/drive/MyDrive/b0_phase2.h5
# /content/drive/MyDrive/best_model_b0.h5

# %%
MODEL_PATH = '/content/drive/MyDrive/best_model_b0.h5'

import os
print("Model exists:", os.path.exists(MODEL_PATH))
# Out:
# Model exists: True

# %%
import tensorflow as tf

MODEL_PATH = '/content/drive/MyDrive/best_model_b0.h5'
model = tf.keras.models.load_model(MODEL_PATH)

print("Model loaded successfully!")
model.summary()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model loaded successfully!
# Model: "efficientnet_b0"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 224, 224,  │          0 │ input_layer_1[0]… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
# %cd /content/Disaster-Severity
# !git pull origin master
# Out:
# /content/Disaster-Severity
# From https://github.com/ipshitabhardwaj/Disaster-Severity
#  * branch            master     -> FETCH_HEAD
# Already up to date.

# %%
# !cat /content/Disaster-Severity/utils/gradcam.py | head -50
# Out:
# """Grad-CAM / Grad-CAM++ explainability utilities for the disaster classifier.
#
# Works with any EfficientNet variant (B0/B1/B3) produced by
# `notebooks/02_model_training.ipynb` — the last Conv2D layer is auto-detected
# rather than hardcoded, since each backbone has a different architecture.
#
# `app/app.py` (Streamlit UI) and `notebooks/03_gradcam.ipynb` /
# `notebooks/04_dashboard_dev.ipynb` both import from here, so heatmap
# generation stays in one place.
# """
#
# from __future__ import annotations
#
# import sys
# from pathlib import Path
# from typing import Dict, Optional, Tuple, Union
#
# import cv2
# import numpy as np
# import tensorflow as tf
# from PIL import Image
#
#
# def find_project_root(marker: str = "data", max_up: int = 5) -> Path:
#     """Walk up from this file until a directory containing `marker/` is found."""
#     cur = Path(__file__).resolve().parent
#     for _ in range(max_up + 1):
#         if (cur / marker).is_dir():
#             return cur
# ...

# %%
import os

# Pehle check karo tumhara actual data drive pe kahan hai
print(os.path.exists('/content/drive/MyDrive/data'))
# Out:
# True

# %%
# !ln -s /content/drive/MyDrive/data /content/Disaster-Severity/data

# %%
import os
print(os.path.exists('/content/Disaster-Severity/data'))
# Out:
# True

# %%
import os
test_folder = '/content/drive/MyDrive/data/Test/Flood/'
print(os.listdir(test_folder)[:5])
# Out:
# ['image_296.png', 'image_259.png', 'image_282.png', 'image_239.png', 'image_255.png']

# %%
import sys
sys.path.append('/content/Disaster-Severity')
from utils.gradcam import predict_and_explain

test_image_path = '/content/drive/MyDrive/data/Test/Flood/image_296.png'

result = predict_and_explain(model, test_image_path)

print("Predicted class:", result['class'])
print("Confidence:", result['confidence'])
print("All probs:", result['all_probs'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/models/functional.py:241: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['input_layer_1']
# Received: inputs=Tensor(shape=(1, 224, 224, 3))
#   warnings.warn(msg)
# Predicted class: Normal
# Confidence: 0.4359668493270874
# All probs: {'Earthquake': 0.27120572328567505, 'Fire': 0.17909790575504303, 'Flood': 0.11372954398393631, 'Normal': 0.4359668493270874}

# %%
test_image_path = '/content/drive/MyDrive/data/Test/Fire/'
import os
print(os.listdir(test_image_path)[:3])
# Out:
# []

# %%
import os
test_folder = '/content/drive/MyDrive/data/Test/'
for cls in os.listdir(test_folder):
    print(repr(cls))
# Out:
# 'Normal'
# 'Flood'
# 'Fire'
# 'Earthquake'

# %%
import os
fire_folder = '/content/drive/MyDrive/data/Test/Fire/'
print("Exists:", os.path.exists(fire_folder))
print("Contents:", os.listdir(fire_folder))
# Out:
# Exists: True
# Contents: []

# %%
import os
test_folder = '/content/drive/MyDrive/data/Test/'
for cls in os.listdir(test_folder):
    path = os.path.join(test_folder, cls)
    count = len(os.listdir(path))
    print(f"{cls}: {count} images")
# Out:
# Normal: 477 images
# Flood: 502 images
# Fire: 0 images
# Earthquake: 239 images

# %%
import os
eq_folder = '/content/drive/MyDrive/data/Test/Earthquake/'
print(os.listdir(eq_folder)[:3])
# Out:
# ['image_156.png', 'image_125.png', 'image_114.png']

# %%
test_image_path = '/content/drive/MyDrive/data/Test/Earthquake/image_156.png'

result = predict_and_explain(model, test_image_path)

print("Predicted class:", result['class'])
print("Confidence:", result['confidence'])
print("All probs:", result['all_probs'])
# Out:
# Predicted class: Normal
# Confidence: 0.4667871594429016
# All probs: {'Earthquake': 0.2690776586532593, 'Fire': 0.13900601863861084, 'Flood': 0.1251291036605835, 'Normal': 0.4667871594429016}

# %%
# !cat /content/Disaster-Severity/app/app.py
# Out:
# import streamlit as st
# import tensorflow as tf
# import numpy as np
# import plotly.graph_objects as go
# import glob
# import tempfile
# import os
# import sys
#
# PROJECT_ROOT = os.path.dirname(os.path.dirname(os.path.abspath(__file__)))
# sys.path.append(PROJECT_ROOT)
# from utils.gradcam import predict_and_explain
# from utils.predict import CLASS_NAMES as PREDICT_CLASS_NAMES
#
# MODEL_PATH = os.path.join(PROJECT_ROOT, 'models', 'best_model.h5')
# TEST_DIR = os.path.join(PROJECT_ROOT, 'data', 'Test')
#
# # ── Page config ──────────────────────────────────────────────
# st.set_page_config(
#     page_title="Disaster Severity Assessment",
#     page_icon="🛰️",
#     layout="wide"
# )
#
# CLASS_NAMES = list(PREDICT_CLASS_NAMES)
# CLASS_COLORS = {
#     'Earthquake': '#e74c3c',
#     'Fire':       '#e67e22',
#     'Flood':      '#3498db',
#     'Normal':     '#2ecc71'
# }
# CLASS_EMOJI = {
#     'Earthquake': '🏚️',
#     'Fire':       '🔥',
#     'Flood':      '🌊',
# ...

# %%
import os
os.makedirs('/content/Disaster-Severity/models', exist_ok=True)
# !cp /content/drive/MyDrive/best_model_b0.h5 /content/Disaster-Severity/models/best_model.h5

print(os.path.exists('/content/Disaster-Severity/models/best_model.h5'))
# Out:
# True

# %%
# !pip install pyngrok -q

from pyngrok import ngrok

# Apna authtoken yahan daalo
ngrok.set_auth_token("3FhMqpqbCRUqaU9VIgSmx4eJaj2_4sy6Qkbbhu9yvmS4fDLnq")

# Purane tunnels band karo agar koi chal rahe hain
ngrok.kill()

# %%
import subprocess
subprocess.Popen([
    "streamlit", "run", "/content/Disaster-Severity/app/app.py",
    "--server.port", "8501",
    "--server.headless", "true"
])

import time
time.sleep(5)  # thoda wait karo server start hone ke liye

public_url = ngrok.connect(8501)
print("Dashboard link:", public_url)
# Out:
# Dashboard link: NgrokTunnel: "https://florist-overshoot-trace.ngrok-free.dev" -> "http://localhost:8501"

# %%
# %cd /content/Disaster-Severity
# !git add .
# !git status
# Out:
# /content/Disaster-Severity
# On branch rishika/streamlit-app
# Your branch is ahead of 'origin/rishika/streamlit-app' by 18 commits.
#   (use "git push" to publish your local commits)
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   data

# %%
# !git config --global user.email "cdac.project43@gmail.com"
# !git config --global user.name "Rishika"

# !git commit -m "Fix model path, integrate real Grad-CAM, test dashboard with ngrok"
# Out:
# [rishika/streamlit-app 5d302d3] Fix model path, integrate real Grad-CAM, test dashboard with ngrok
#  1 file changed, 1 insertion(+)
#  create mode 120000 data

# %%
# !git remote set-url origin https://rishikx08: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@github.com/ipshitabhardwaj/Disaster-Severity.git
# !git push origin rishika/streamlit-app
# Out:
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 336 bytes | 336.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/ipshitabhardwaj/Disaster-Severity.git
#    a4599a8..5d302d3  rishika/streamlit-app -> rishika/streamlit-app
